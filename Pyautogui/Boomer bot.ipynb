# %%
import pyautogui as pg

# %%
import time
import datetime

# %%
time.sleep(5)

for i in range(200):
    pg.typewrite('Goda')
    pg.keyDown('enter')

# %%
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
Goda
